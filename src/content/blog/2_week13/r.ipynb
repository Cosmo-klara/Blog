# %%
import numpy as np
import matplotlib.pyplot as plt

scores = np.array([
0.6308985948562622,
    0.6120700240135193,
    0.639283299446106,
    0.7529501914978027,
    0.4844280183315277,
    0.5032389163970947,
    0.6409833431243896,
    0.6373642086982727,
    0.8392089009284973,
    1.0383998155593872,
    1.1498119831085205,
    1.48581862449646,
    1.683936595916748,
    1.7976069450378418,
    1.6195608377456665,
    1.6671712398529053,
    1.588405966758728,
    1.3153586387634277,
    1.2926141023635864,
    1.1051061153411865,
    0.9421408772468567,
    1.0110502243041992,
    0.885692834854126,
    0.9810004830360413,
    0.7117451429367065,
    0.6684619784355164,
    0.2887495756149292
])
acc = np.array(
    [
    1671.0656,
    0,
    1639.3589,
    0,
    1652.6073,
    0,
    1596.5615,
    0,
    1617.2901,
    0,
    1640.9723,
    0,
    1645.3759,
    1666.2786,
    1659.3434,
    0,
    1624.0874,
    0,
    1687.3123,
    0,
    1684.7127,
    0,
    1684.4352,
    0,
    1683.0490,
    0,
    ]
    )

n = min(len(scores), len(acc))
scores_aligned = scores[:n]
acc_aligned = acc[:n]

acc_aligned = acc_aligned * 100

mask = acc_aligned != 0
scores_filtered = scores_aligned[mask]
acc_filtered = acc_aligned[mask]


if len(scores_filtered) >= 2:
    r = np.corrcoef(scores_filtered, acc_filtered)[0,1]
    print()
    print('='*50)
    print(f'  Pearson r = {r:.8f}')
    print(f'  R^2       = {r**2:.8f}')
    print('='*50)
# Out:
# ...
#   Pearson r = 0.06167935
#   R^2       = 0.00380434
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

scores = np.array([
    1.0,
    0.9042591452598572,
    0.6297183632850647,
    0.5115534663200378,
    0.517296552658081,
    0.5244174599647522,
    0.49593988060951233,
    0.6330571174621582,
    0.7720574736595154,
    0.8897863626480103,
    1.0633721351623535,
    1.113618016242981,
    1.0536943674087524,
    1.028139352798462,
    1.0073813199996948,
    0.9675173759460449,
    0.905463457107544,
    0.8517112731933594,
    0.7906076908111572,
    0.7809137105941772,
    0.7805154919624329,
    0.7137740850448608,
    0.736487090587616,
    0.718579113483429,
    0.7447505593299866,
    0.7209989428520203,
    0.7170257568359375,
    0.6847683191299438,
    0.48108941316604614,
    0.41200682520866394,
    0.0821443647146225
])
acc = np.array(
    [
    0,
    0,
    0,
    0,
    1322.6942,
    1347.0310,
    1336.9057,
    0,
    1076.2971,
    0,
    893.4799,
    1148.3629,
    1465.7929,
    0,
    1498.3323,
    0,
    1495.4965,
    0,
    1496.0406,
    0,
    1491.2906,
    0,
    1493.3347,
    0,
    1486.5700,
    0,
    ]
    )

n = min(len(scores), len(acc))
scores_aligned = scores[:n]
acc_aligned = acc[:n]

acc_aligned = acc_aligned * 100

mask = acc_aligned != 0
scores_filtered = scores_aligned[mask]
acc_filtered = acc_aligned[mask]

if len(scores_filtered) >= 2:
    r = np.corrcoef(scores_filtered, acc_filtered)[0,1]
    print()
    print('='*50)
    print(f'  Pearson r = {r:.8f}')
    print(f'  R^2       = {r**2:.8f}')
    print('='*50)
# Out:
# ...
#   Pearson r = -0.21704841
#   R^2       = 0.04711001
# ...
