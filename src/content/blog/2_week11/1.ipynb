# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.sans-serif"] = ["SimHei", "Microsoft YaHei", "Noto Sans CJK SC"]
plt.rcParams["axes.unicode_minus"] = False

layer_scores = [
    0.12617972493171692,
    0.1224140077829361,
    0.12785665690898895,
    0.15059004724025726,
    0.09688560664653778,
    0.10064778476953506,
    0.12819667160511017,
    0.12747284770011902,
    0.39163079857826233,
    0.6823770403862,
    0.9198495745658875,
    1.3537458181381226,
    1.683936595916748,
    1.7976069450378418,
    1.6195608377456665,
    1.6671712398529053,
    1.588405966758728,
    1.3153586387634277,
    1.2926141023635864,
    1.1051061153411865,
    0.9421408772468567,
    1.0110502243041992,
    0.885692834854126,
    0.9810004830360413,
    0.7117451429367065,
    0.6684619784355164,
    0.2887495756149292
]

layers = np.arange(len(layer_scores))  # 0..35

fig, ax = plt.subplots(figsize=(10, 4.8), dpi=120)
ax.plot(layers, layer_scores, linewidth=2, marker="o", markersize=3)
ax.set_xlabel("Layer")
ax.set_ylabel("Score")
ax.set_xticks(layers)
ax.grid(True, linestyle="--", alpha=0.3)
fig.tight_layout()
plt.show()

prune_layers = list(range(33))
overall_accuracy = [
    1671.0656,
    0,
    1639.3589,
    0,
    1652.6073,
    0,
    1596.5615,
    0,
    1617.2901,
    0,
    1640.9723,
    0,
    1645.3759,
    1666.2786,
    1659.3434,
    0,
    1624.0874
]
overall_accuracy_pct = [a * 100 for a in overall_accuracy]
scores_0_32 = np.array(layer_scores[:33])

fig, ax = plt.subplots(figsize=(10, 6.8), dpi=120)
ax.scatter(scores_0_32, overall_accuracy_pct, s=60, color="#2f2f2f")

for layer, score, acc in zip(prune_layers, scores_0_32, overall_accuracy_pct):
    ax.annotate(f"layer{layer}", xy=(score, acc), xytext=(6, 6), textcoords="offset points", fontsize=8)

ax.set_xlabel("Score", fontsize=12)
ax.set_ylabel("Accuracy(%)", fontsize=12)
ax.grid(True, linestyle="--", alpha=0.3)
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 72
#      69 scores_0_32 = np.array(layer_scores[:33])
#      71 fig, ax = plt.subplots(figsize=(10, 6.8), dpi=120)
# ---> 72 ax.scatter(scores_0_32, overall_accuracy_pct, s=60, color="#2f2f2f")
#      74 for layer, score, acc in zip(prune_layers, scores_0_32, overall_accuracy_pct):
#      75     ax.annotate(f"layer{layer}", xy=(score, acc), xytext=(6, 6), textcoords="offset points", fontsize=8)
#
# File d:\Cache\PythonLib\envs\GSV\lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
# ...
